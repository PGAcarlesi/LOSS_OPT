# %%
import numpy as np
import matplotlib.pyplot as plt
def adaptive_los(x,alpha,c):
    return np.abs(alpha-2)/alpha *(((x/c)**2/np.abs(alpha-2)+1)**(alpha-2)-1)

# %%
alpha=np.linspace(1,10,1000)
x=0.5
c=0.5
plt.plot(alpha,adaptive_los(x,alpha,c))
# Out:
# /var/folders/3j/3sftgpw558d6tvmshw2b29jc0000gn/T/ipykernel_5344/2881391120.py:4: RuntimeWarning: divide by zero encountered in divide
#   return np.abs(alpha-2)/alpha *(((x/c)**2/np.abs(alpha-2)+1)**(alpha-2)-1)
